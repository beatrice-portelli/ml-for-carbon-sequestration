# %%
import os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.model_selection import KFold, RepeatedKFold, LeaveOneOut

from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor

from sklearn.metrics import (
    mean_squared_error,
    r2_score,
    mean_absolute_percentage_error
)

from tqdm.auto import tqdm

from copy import deepcopy

import warnings
from sklearn.exceptions import ConvergenceWarning
warnings.filterwarnings(action='ignore', category=ConvergenceWarning)

def root_mean_squared_error(y_true, y_pred):
    return mean_squared_error(y_true, y_pred, squared=False)


def normalized_root_mean_squared_error(y_true, y_pred, norm_factor=None):
    if norm_factor is None:
        assert False, "Set norm_factor (for example the average target value for the training set)"
    rmse = root_mean_squared_error(y_true, y_pred)
    return (rmse / norm_factor)*100

from configs import *
from experiments_to_run import MODELS, CONFIGS, TARGETS


OVERWRITE = False


total_iterations = len(MODELS)*len(CONFIGS)*len(TARGETS)
curr_iteration = 0

for MODEL in MODELS:
    for CONFIG in CONFIGS:
        for TARGET in TARGETS:
            
            curr_iteration+=1
            print(f"---------------- [{curr_iteration} / {total_iterations}]")
            
            if not OVERWRITE:
                conf = f"{TARGET}--{CONFIG.name}--{MODEL[0](_).__class__.__name__}"
                save_path = f"results/metrics--{conf}.pickle"
                if os.path.exists(save_path):
                    print("File already exists. Skipping", conf)
                    continue
                else:
                    print("Running", conf)

            # fixing random seed as soon as possible
            # for reproducibility
            np.random.seed(123)

            df = pd.read_csv("../INFC_2015_climatic.csv")
            X = df[CONFIG.features]
            y = df[TARGET]

            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

            model_class, param_distributions, search_cv_args = MODEL
            
            if param_distributions is None:
                
                regressor = model_class(_)
            
            else:
                
                search_cv = RandomizedSearchCV(
                    model_class(_), param_distributions=param_distributions,
                    scoring="neg_mean_squared_error", random_state=0, **search_cv_args
                )
                search_cv.fit(X_train, y_train)

                print("The best hyperparameters are ",search_cv.best_params_)
                
                if type(search_cv.estimator) not in [
                    KNeighborsRegressor,
                    SVR
                ]:
                    regressor = model_class(_).set_params( # use search_cv.estimator, to make it independent from the estimator's class
                        random_state=0,           # fixed random state
                        **search_cv.best_params_, # pass all parameters without to need to manually assign them
                    )
                else:
                    regressor = model_class(_).set_params( # use search_cv.estimator, to make it independent from the estimator's class
                        **search_cv.best_params_, # pass all parameters without to need to manually assign them
                    )

            data = []
            
            # =================================================================
            # the following code is an alternative, to split the dataset in
            # 66/33 random train/test splits for 10 times to run the evaluation
            
            folds = []

            for random_state in range(10):
                cv = KFold(n_splits=4, random_state=random_state, shuffle=True)
                tmp_folds = cv.split(X)
                folds.append(next(tmp_folds))
                

            for i, (train_index, test_index) in enumerate(folds):

                X_train = X.iloc[train_index]
                y_train = y.iloc[train_index].values

                X_test = X.iloc[test_index]
                y_test = y.iloc[test_index].values

                regressor.fit(X_train, y_train)
                y_pred = regressor.predict(X_test)

                data.append({
                    "target": TARGET,
                    "config": CONFIG.name,
                    "model": regressor.__class__.__name__,
                    "hyperparams": None if param_distributions is None else search_cv.best_params_,
                    "fold": i,
                    "X_train": X_train,
                    "y_train": y_train,
                    "X_test": X_test,
                    "y_test": y_test,
                    "y_pred": y_pred,
                    "model_obj": deepcopy(regressor),
                })

            data = pd.DataFrame(data)
            save_path = f"results/predictions--{TARGET}--{CONFIG.name}--{regressor.__class__.__name__}.pickle"
            data.to_pickle(save_path)
            # print("predictions saved to", save_path)
            # display(data)

            data["MSE"] = data.apply(lambda row: mean_squared_error(row.y_test, row.y_pred), axis=1)
            data["R2"] = data.apply(lambda row: r2_score(row.y_test, row.y_pred), axis=1)
            data["MAPE"] = data.apply(lambda row: mean_absolute_percentage_error(row.y_test, row.y_pred), axis=1)
            data["RMSE"] = data.apply(lambda row: root_mean_squared_error(row.y_test, row.y_pred), axis=1)
            data["NRMSE"] = data.apply(lambda row: normalized_root_mean_squared_error(row.y_test, row.y_pred, norm_factor=row.y_train.mean()), axis=1)

            data = data.drop(columns=["X_train", "y_train", "X_test", "y_test", "y_pred"])
            save_path = f"results/metrics--{TARGET}--{CONFIG.name}--{regressor.__class__.__name__}.pickle"
            data.to_pickle(save_path)
            print("metrics, predictions and models saved to\n", save_path)
            # display(data)

            for metric in ["R2", "MAPE", "RMSE", "NRMSE"]:

                print(f"{metric:>10} {data[metric].mean().round(2):>7} ± {data[metric].std().round(2):>5}")
# Out:
# ---------------- [1 / 64]
# Running Catot_ha--CONFIG_0--MLPRegressor
# The best hyperparameters are  {'max_iter': 50, 'learning_rate_init': 0.01, 'hidden_layer_sizes': [8]}
# metrics, predictions and models saved to
#  results/metrics--Catot_ha--CONFIG_0--MLPRegressor.pickle
#         R2    0.11 ±  0.12
#       MAPE    3.12 ±  2.46
#       RMSE   57.99 ±  7.15
#      NRMSE   75.43 ± 10.62
# ---------------- [2 / 64]
# Running ICCapv_ha--CONFIG_0--MLPRegressor
# The best hyperparameters are  {'max_iter': 20, 'learning_rate_init': 0.1, 'hidden_layer_sizes': [8]}
# metrics, predictions and models saved to
#  results/metrics--ICCapv_ha--CONFIG_0--MLPRegressor.pickle
#         R2   -0.02 ±  0.03
#       MAPE    2.41 ±   1.2
#       RMSE    1.17 ±   0.1
#      NRMSE   68.88 ±  7.05
# ---------------- [3 / 64]
# Running Catot_ha--CONFIG_1--MLPRegressor
# The best hyperparameters are  {'max_iter': 50, 'learning_rate_init': 0.01, 'hidden_layer_sizes': [4]}
# metrics, predictions and models saved to
#  results/metrics--Catot_ha--CONFIG_1--MLPRegressor.pickle
#         R2    0.61 ±  0.05
#       MAPE    0.75 ±  0.45
#       RMSE   38.39 ±  5.07
#      NRMSE   49.96 ±  7.68
# ---------------- [4 / 64]
# Running ICCapv_ha--CONFIG_1--MLPRegressor
# The best hyperparameters are  {'max_iter': 50, 'learning_rate_init': 0.1, 'hidden_layer_sizes': [2]}
# metrics, predictions and models saved to
#  results/metrics--ICCapv_ha--CONFIG_1--MLPRegressor.pickle
#         R2   -0.02 ±  0.03
#       MAPE     2.4 ±  1.21
#       RMSE    1.17 ±   0.1
#      NRMSE   68.85 ±   7.1
# ---------------- [5 / 64]
# Running Catot_ha--CONFIG_2--MLPRegressor
# The best hyperparameters are  {'max_iter': 50, 'learning_rate_init': 0.01, 'hidden_layer_sizes': [8]}
# metrics, predictions and models saved to
#  results/metrics--Catot_ha--CONFIG_2--MLPRegressor.pickle
#         R2    0.49 ±   0.2
#       MAPE    0.98 ±  0.62
#       RMSE   42.98 ±  8.78
#      NRMSE   55.92 ± 12.06
# ---------------- [6 / 64]
# Running ICCapv_ha--CONFIG_2--MLPRegressor
# The best hyperparameters are  {'max_iter': 50, 'learning_rate_init': 0.1, 'hidden_layer_sizes': [2]}
# metrics, predictions and models saved to
#  results/metrics--ICCapv_ha--CONFIG_2--MLPRegressor.pickle
#         R2   -0.02 ±  0.04
#       MAPE    2.43 ±  1.21
#       RMSE    1.17 ±   0.1
#      NRMSE   68.97 ±  6.97
# ---------------- [7 / 64]
# Running Catot_ha--CONFIG_3--MLPRegressor
# The best hyperparameters are  {'max_iter': 50, 'learning_rate_init': 0.01, 'hidden_layer_sizes': [8]}
# metrics, predictions and models saved to
#  results/metrics--Catot_ha--CONFIG_3--MLPRegressor.pickle
#         R2    0.21 ±  0.09
#       MAPE    3.39 ±  2.85
#       RMSE   54.31 ±  4.96
#      NRMSE   70.63 ±  7.75
# ---------------- [8 / 64]
# Running ICCapv_ha--CONFIG_3--MLPRegressor
# The best hyperparameters are  {'max_iter': 50, 'learning_rate_init': 0.1, 'hidden_layer_sizes': [2]}
# metrics, predictions and models saved to
#  results/metrics--ICCapv_ha--CONFIG_3--MLPRegressor.pickle
#         R2   -0.02 ±  0.04
#       MAPE    2.44 ±   1.2
#       RMSE    1.17 ±   0.1
#      NRMSE   68.95 ±   6.9
# ---------------- [9 / 64]
# Running Catot_ha--CONFIG_0--SVR
# /media/HDD/bportelli/env/lib/python3.8/site-packages/sklearn/model_selection/_search.py:285: UserWarning: The total space of parameters 20 is smaller than n_iter=30. Running 20 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# The best hyperparameters are  {'gamma': 1e-05, 'C': 10}
# metrics, predictions and models saved to
#  results/metrics--Catot_ha--CONFIG_0--SVR.pickle
#         R2    0.18 ±  0.06
#       MAPE    2.93 ±  2.35
#       RMSE   55.44 ±  6.09
#      NRMSE   72.13 ±  9.56
# ---------------- [10 / 64]
# Running ICCapv_ha--CONFIG_0--SVR
# /media/HDD/bportelli/env/lib/python3.8/site-packages/sklearn/model_selection/_search.py:285: UserWarning: The total space of parameters 20 is smaller than n_iter=30. Running 20 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# The best hyperparameters are  {'gamma': 1e-05, 'C': 1}
# metrics, predictions and models saved to
#  results/metrics--ICCapv_ha--CONFIG_0--SVR.pickle
#         R2   -0.06 ±  0.09
#       MAPE    1.93 ±  1.13
#       RMSE    1.19 ±  0.11
#      NRMSE    70.1 ±  7.71
# ---------------- [11 / 64]
# Running Catot_ha--CONFIG_1--SVR
# /media/HDD/bportelli/env/lib/python3.8/site-packages/sklearn/model_selection/_search.py:285: UserWarning: The total space of parameters 20 is smaller than n_iter=30. Running 20 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# The best hyperparameters are  {'gamma': 1e-05, 'C': 10}
# metrics, predictions and models saved to
#  results/metrics--Catot_ha--CONFIG_1--SVR.pickle
#         R2     0.2 ±  0.06
#       MAPE    2.75 ±  2.09
#       RMSE   54.84 ±  6.33
#      NRMSE   71.36 ±  9.84
# ---------------- [12 / 64]
# Running ICCapv_ha--CONFIG_1--SVR
# /media/HDD/bportelli/env/lib/python3.8/site-packages/sklearn/model_selection/_search.py:285: UserWarning: The total space of parameters 20 is smaller than n_iter=30. Running 20 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# The best hyperparameters are  {'gamma': 1e-05, 'C': 1}
# metrics, predictions and models saved to
#  results/metrics--ICCapv_ha--CONFIG_1--SVR.pickle
#         R2    0.05 ±   0.1
#       MAPE    1.77 ±   0.9
#       RMSE    1.12 ±  0.09
#      NRMSE   66.18 ±  6.25
# ---------------- [13 / 64]
# Running Catot_ha--CONFIG_2--SVR
# /media/HDD/bportelli/env/lib/python3.8/site-packages/sklearn/model_selection/_search.py:285: UserWarning: The total space of parameters 20 is smaller than n_iter=30. Running 20 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# The best hyperparameters are  {'gamma': 1e-05, 'C': 1000}
# metrics, predictions and models saved to
#  results/metrics--Catot_ha--CONFIG_2--SVR.pickle
#         R2    0.31 ±  0.08
#       MAPE    1.24 ±  0.55
#       RMSE   51.06 ±  5.72
#      NRMSE    66.4 ±  8.58
# ---------------- [14 / 64]
# Running ICCapv_ha--CONFIG_2--SVR
# /media/HDD/bportelli/env/lib/python3.8/site-packages/sklearn/model_selection/_search.py:285: UserWarning: The total space of parameters 20 is smaller than n_iter=30. Running 20 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# The best hyperparameters are  {'gamma': 1e-05, 'C': 10}
# metrics, predictions and models saved to
#  results/metrics--ICCapv_ha--CONFIG_2--SVR.pickle
#         R2    0.02 ±  0.12
#       MAPE    1.68 ±  0.96
#       RMSE    1.14 ±   0.1
#      NRMSE   67.09 ±  6.94
# ---------------- [15 / 64]
# Running Catot_ha--CONFIG_3--SVR
# /media/HDD/bportelli/env/lib/python3.8/site-packages/sklearn/model_selection/_search.py:285: UserWarning: The total space of parameters 20 is smaller than n_iter=30. Running 20 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# The best hyperparameters are  {'gamma': 1e-05, 'C': 10}
# metrics, predictions and models saved to
#  results/metrics--Catot_ha--CONFIG_3--SVR.pickle
#         R2     0.2 ±  0.06
#       MAPE    2.78 ±  2.13
#       RMSE    55.0 ±  6.33
#      NRMSE   71.58 ±  9.85
# ---------------- [16 / 64]
# Running ICCapv_ha--CONFIG_3--SVR
# /media/HDD/bportelli/env/lib/python3.8/site-packages/sklearn/model_selection/_search.py:285: UserWarning: The total space of parameters 20 is smaller than n_iter=30. Running 20 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# The best hyperparameters are  {'gamma': 0.0001, 'C': 10}
# metrics, predictions and models saved to
#  results/metrics--ICCapv_ha--CONFIG_3--SVR.pickle
#         R2     0.0 ±  0.12
#       MAPE    2.09 ±  1.02
#       RMSE    1.15 ±  0.08
#      NRMSE   67.76 ±  5.28
# ---------------- [17 / 64]
# Running Catot_ha--CONFIG_0--KNeighborsRegressor
# The best hyperparameters are  {'n_neighbors': 17}
# metrics, predictions and models saved to
#  results/metrics--Catot_ha--CONFIG_0--KNeighborsRegressor.pickle
#         R2    0.25 ±  0.08
#       MAPE     3.4 ±  2.78
#       RMSE    53.1 ±  4.47
#      NRMSE   69.05 ±  7.22
# ---------------- [18 / 64]
# Running ICCapv_ha--CONFIG_0--KNeighborsRegressor
# The best hyperparameters are  {'n_neighbors': 16}
# metrics, predictions and models saved to
#  results/metrics--ICCapv_ha--CONFIG_0--KNeighborsRegressor.pickle
#         R2   -0.03 ±  0.09
#       MAPE    2.28 ±  1.31
#       RMSE    1.17 ±  0.09
#      NRMSE   68.97 ±  6.37
# ---------------- [19 / 64]
# Running Catot_ha--CONFIG_1--KNeighborsRegressor
# The best hyperparameters are  {'n_neighbors': 21}
# metrics, predictions and models saved to
#  results/metrics--Catot_ha--CONFIG_1--KNeighborsRegressor.pickle
#         R2    0.28 ±  0.07
#       MAPE    3.42 ±  2.86
#       RMSE   52.07 ±  4.79
#      NRMSE   67.71 ±  7.58
# ---------------- [20 / 64]
# Running ICCapv_ha--CONFIG_1--KNeighborsRegressor
# The best hyperparameters are  {'n_neighbors': 14}
# metrics, predictions and models saved to
#  results/metrics--ICCapv_ha--CONFIG_1--KNeighborsRegressor.pickle
#         R2    0.07 ±  0.07
#       MAPE    2.11 ±  1.18
#       RMSE    1.11 ±  0.08
#      NRMSE   65.67 ±  5.77
# ---------------- [21 / 64]
# Running Catot_ha--CONFIG_2--KNeighborsRegressor
# The best hyperparameters are  {'n_neighbors': 17}
# metrics, predictions and models saved to
#  results/metrics--Catot_ha--CONFIG_2--KNeighborsRegressor.pickle
#         R2    0.25 ±  0.08
#       MAPE    3.39 ±  2.78
#       RMSE   53.02 ±   4.5
#      NRMSE   68.94 ±  7.25
# ---------------- [22 / 64]
# Running ICCapv_ha--CONFIG_2--KNeighborsRegressor
# The best hyperparameters are  {'n_neighbors': 16}
# metrics, predictions and models saved to
#  results/metrics--ICCapv_ha--CONFIG_2--KNeighborsRegressor.pickle
#         R2   -0.02 ±  0.08
#       MAPE    2.26 ±   1.3
#       RMSE    1.17 ±  0.09
#      NRMSE   68.79 ±  6.44
# ---------------- [23 / 64]
# Running Catot_ha--CONFIG_3--KNeighborsRegressor
# The best hyperparameters are  {'n_neighbors': 21}
# metrics, predictions and models saved to
#  results/metrics--Catot_ha--CONFIG_3--KNeighborsRegressor.pickle
#         R2    0.27 ±  0.08
#       MAPE    3.42 ±  2.86
#       RMSE   52.14 ±  4.77
#      NRMSE    67.8 ±  7.55
# ---------------- [24 / 64]
# Running ICCapv_ha--CONFIG_3--KNeighborsRegressor
# The best hyperparameters are  {'n_neighbors': 14}
# metrics, predictions and models saved to
#  results/metrics--ICCapv_ha--CONFIG_3--KNeighborsRegressor.pickle
#         R2    0.06 ±  0.07
#       MAPE    2.11 ±  1.18
#       RMSE    1.12 ±  0.08
#      NRMSE   65.84 ±  5.78
# ---------------- [25 / 64]
# Running Catot_ha--CONFIG_0--LinearRegression
# metrics, predictions and models saved to
#  results/metrics--Catot_ha--CONFIG_0--LinearRegression.pickle
#         R2    0.11 ±  0.11
#       MAPE    3.29 ±  2.45
#       RMSE    57.8 ±  4.88
#      NRMSE   75.09 ±   6.9
# ---------------- [26 / 64]
# Running ICCapv_ha--CONFIG_0--LinearRegression
# metrics, predictions and models saved to
#  results/metrics--ICCapv_ha--CONFIG_0--LinearRegression.pickle
#         R2    0.13 ±  0.13
#       MAPE    1.55 ±  0.55
#       RMSE    1.07 ±  0.09
#      NRMSE   63.21 ±  5.73
# ---------------- [27 / 64]
# Running Catot_ha--CONFIG_1--LinearRegression
# metrics, predictions and models saved to
#  results/metrics--Catot_ha--CONFIG_1--LinearRegression.pickle
#         R2    0.59 ±  0.07
#       MAPE    1.02 ±  0.42
#       RMSE    38.9 ±  3.47
#      NRMSE   50.56 ±  5.37
# ---------------- [28 / 64]
# Running ICCapv_ha--CONFIG_1--LinearRegression
# metrics, predictions and models saved to
#  results/metrics--ICCapv_ha--CONFIG_1--LinearRegression.pickle
#         R2    0.32 ±  0.11
#       MAPE    1.03 ±  0.29
#       RMSE    0.95 ±   0.1
#      NRMSE   56.06 ±  6.71
# ---------------- [29 / 64]
# Running Catot_ha--CONFIG_2--LinearRegression
# metrics, predictions and models saved to
#  results/metrics--Catot_ha--CONFIG_2--LinearRegression.pickle
#         R2    0.61 ±  0.05
#       MAPE    0.81 ±  0.22
#       RMSE   38.16 ±  3.52
#      NRMSE   49.61 ±  5.44
# ---------------- [30 / 64]
# Running ICCapv_ha--CONFIG_2--LinearRegression
# metrics, predictions and models saved to
#  results/metrics--ICCapv_ha--CONFIG_2--LinearRegression.pickle
#         R2     0.3 ±  0.11
#       MAPE    1.02 ±  0.35
#       RMSE    0.97 ±  0.11
#      NRMSE   56.96 ±  7.03
# ---------------- [31 / 64]
# Running Catot_ha--CONFIG_3--LinearRegression
# metrics, predictions and models saved to
#  results/metrics--Catot_ha--CONFIG_3--LinearRegression.pickle
#         R2    0.02 ±  0.13
#       MAPE    3.19 ±  2.35
#       RMSE   60.37 ±   3.6
#      NRMSE   78.41 ±   5.4
# ---------------- [32 / 64]
# Running ICCapv_ha--CONFIG_3--LinearRegression
# metrics, predictions and models saved to
#  results/metrics--ICCapv_ha--CONFIG_3--LinearRegression.pickle
#         R2    0.14 ±  0.14
#       MAPE    1.46 ±  0.46
#       RMSE    1.07 ±  0.08
#      NRMSE   62.88 ±  5.62
# ---------------- [33 / 64]
# Running Catot_ha--CONFIG_0--RandomForestRegressor
# The best hyperparameters are  {'n_estimators': 600, 'min_samples_split': 16, 'min_samples_leaf': 5, 'max_features': 4, 'max_depth': 110, 'bootstrap': True}
# metrics, predictions and models saved to
#  results/metrics--Catot_ha--CONFIG_0--RandomForestRegressor.pickle
#         R2     0.3 ±  0.04
#       MAPE    2.57 ±  1.65
#       RMSE   51.17 ±  4.96
#      NRMSE   66.56 ±  7.88
# ---------------- [34 / 64]
# Running ICCapv_ha--CONFIG_0--RandomForestRegressor
# The best hyperparameters are  {'n_estimators': 400, 'min_samples_split': 16, 'min_samples_leaf': 4, 'max_features': 4, 'max_depth': 150, 'bootstrap': True}
# metrics, predictions and models saved to
#  results/metrics--ICCapv_ha--CONFIG_0--RandomForestRegressor.pickle
#         R2    0.28 ±  0.09
#       MAPE    1.56 ±  0.65
#       RMSE    0.98 ±  0.11
#      NRMSE   57.77 ±  7.32
# ---------------- [35 / 64]
# Running Catot_ha--CONFIG_1--RandomForestRegressor
# The best hyperparameters are  {'n_estimators': 1200, 'min_samples_split': 10, 'min_samples_leaf': 6, 'max_features': 6, 'max_depth': 120, 'bootstrap': True}
# metrics, predictions and models saved to
#  results/metrics--Catot_ha--CONFIG_1--RandomForestRegressor.pickle
#         R2    0.66 ±  0.06
#       MAPE    1.48 ±  0.94
#       RMSE   35.53 ±  5.51
#      NRMSE   46.24 ±  8.09
# ---------------- [36 / 64]
# Running ICCapv_ha--CONFIG_1--RandomForestRegressor
# The best hyperparameters are  {'n_estimators': 1000, 'min_samples_split': 10, 'min_samples_leaf': 5, 'max_features': 6, 'max_depth': 150, 'bootstrap': True}
# metrics, predictions and models saved to
#  results/metrics--ICCapv_ha--CONFIG_1--RandomForestRegressor.pickle
#         R2    0.42 ±   0.1
#       MAPE    1.22 ±  0.47
#       RMSE    0.88 ±  0.13
#      NRMSE   52.01 ±  8.29
# ---------------- [37 / 64]
# Running Catot_ha--CONFIG_2--RandomForestRegressor
# The best hyperparameters are  {'n_estimators': 1000, 'min_samples_split': 10, 'min_samples_leaf': 5, 'max_features': 6, 'max_depth': 150, 'bootstrap': True}
# metrics, predictions and models saved to
#  results/metrics--Catot_ha--CONFIG_2--RandomForestRegressor.pickle
#         R2    0.69 ±  0.06
#       MAPE    1.26 ±  0.77
#       RMSE   34.36 ±   5.4
#      NRMSE   44.72 ±  7.92
# ---------------- [38 / 64]
# Running ICCapv_ha--CONFIG_2--RandomForestRegressor
# The best hyperparameters are  {'n_estimators': 1000, 'min_samples_split': 10, 'min_samples_leaf': 5, 'max_features': 6, 'max_depth': 150, 'bootstrap': True}
# metrics, predictions and models saved to
#  results/metrics--ICCapv_ha--CONFIG_2--RandomForestRegressor.pickle
#         R2    0.42 ±   0.1
#       MAPE    1.15 ±  0.43
#       RMSE    0.88 ±  0.13
#      NRMSE   51.83 ±  8.56
# ---------------- [39 / 64]
# Running Catot_ha--CONFIG_3--RandomForestRegressor
# The best hyperparameters are  {'n_estimators': 1000, 'min_samples_split': 10, 'min_samples_leaf': 5, 'max_features': 6, 'max_depth': 150, 'bootstrap': True}
# metrics, predictions and models saved to
#  results/metrics--Catot_ha--CONFIG_3--RandomForestRegressor.pickle
#         R2    0.32 ±  0.04
#       MAPE     2.5 ±  1.61
#       RMSE    50.7 ±  4.57
#      NRMSE   65.93 ±  7.39
# ---------------- [40 / 64]
# Running ICCapv_ha--CONFIG_3--RandomForestRegressor
# The best hyperparameters are  {'n_estimators': 1000, 'min_samples_split': 10, 'min_samples_leaf': 5, 'max_features': 6, 'max_depth': 150, 'bootstrap': True}
# metrics, predictions and models saved to
#  results/metrics--ICCapv_ha--CONFIG_3--RandomForestRegressor.pickle
#         R2    0.28 ±  0.09
#       MAPE    1.53 ±  0.64
#       RMSE    0.98 ±  0.12
#      NRMSE   57.69 ±  7.68
# ---------------- [41 / 64]
# Running Catot_ha--CONFIG_0--GradientBoostingRegressor
# The best hyperparameters are  {'subsample': 0.75, 'n_estimators': 100, 'max_leaf_nodes': 100, 'max_depth': 2, 'learning_rate': 0.1}
# metrics, predictions and models saved to
#  results/metrics--Catot_ha--CONFIG_0--GradientBoostingRegressor.pickle
#         R2     0.3 ±  0.05
#       MAPE     2.1 ±  1.15
#       RMSE   51.33 ±  5.04
#      NRMSE   66.76 ±  7.93
# ---------------- [42 / 64]
# Running ICCapv_ha--CONFIG_0--GradientBoostingRegressor
# The best hyperparameters are  {'subsample': 0.75, 'n_estimators': 10, 'max_leaf_nodes': 5, 'max_depth': 4, 'learning_rate': 0.1}
# metrics, predictions and models saved to
#  results/metrics--ICCapv_ha--CONFIG_0--GradientBoostingRegressor.pickle
#         R2    0.21 ±  0.06
#       MAPE    1.88 ±  0.86
#       RMSE    1.03 ±  0.12
#      NRMSE   60.68 ±  8.05
# ---------------- [43 / 64]
# Running Catot_ha--CONFIG_1--GradientBoostingRegressor
# The best hyperparameters are  {'subsample': 0.75, 'n_estimators': 100, 'max_leaf_nodes': 100, 'max_depth': 2, 'learning_rate': 0.1}
# metrics, predictions and models saved to
#  results/metrics--Catot_ha--CONFIG_1--GradientBoostingRegressor.pickle
#         R2    0.68 ±  0.07
#       MAPE    0.88 ±  0.43
#       RMSE    34.8 ±  5.46
#      NRMSE   45.27 ±  7.88
# ---------------- [44 / 64]
# Running ICCapv_ha--CONFIG_1--GradientBoostingRegressor
# The best hyperparameters are  {'subsample': 1, 'n_estimators': 1000, 'max_leaf_nodes': 100, 'max_depth': 4, 'learning_rate': 0.01}
# metrics, predictions and models saved to
#  results/metrics--ICCapv_ha--CONFIG_1--GradientBoostingRegressor.pickle
#         R2    0.33 ±   0.1
#       MAPE    1.17 ±  0.49
#       RMSE    0.94 ±  0.13
#      NRMSE   55.74 ±  8.47
# ---------------- [45 / 64]
# Running Catot_ha--CONFIG_2--GradientBoostingRegressor
# The best hyperparameters are  {'subsample': 1, 'n_estimators': 1000, 'max_leaf_nodes': 100, 'max_depth': 4, 'learning_rate': 0.01}
# metrics, predictions and models saved to
#  results/metrics--Catot_ha--CONFIG_2--GradientBoostingRegressor.pickle
#         R2    0.67 ±  0.06
#       MAPE    0.66 ±  0.27
#       RMSE    35.2 ±  5.63
#      NRMSE   45.81 ±  8.06
# ---------------- [46 / 64]
# Running ICCapv_ha--CONFIG_2--GradientBoostingRegressor
# The best hyperparameters are  {'subsample': 1, 'n_estimators': 1000, 'max_leaf_nodes': 100, 'max_depth': 4, 'learning_rate': 0.01}
# metrics, predictions and models saved to
#  results/metrics--ICCapv_ha--CONFIG_2--GradientBoostingRegressor.pickle
#         R2    0.33 ±   0.1
#       MAPE    1.15 ±  0.42
#       RMSE    0.95 ±  0.12
#      NRMSE   55.85 ±  8.12
# ---------------- [47 / 64]
# Running Catot_ha--CONFIG_3--GradientBoostingRegressor
# The best hyperparameters are  {'subsample': 1, 'n_estimators': 1000, 'max_leaf_nodes': 100, 'max_depth': 4, 'learning_rate': 0.01}
# metrics, predictions and models saved to
#  results/metrics--Catot_ha--CONFIG_3--GradientBoostingRegressor.pickle
#         R2    0.27 ±   0.1
#       MAPE    2.06 ±  1.01
#       RMSE   52.24 ±  5.45
#      NRMSE   67.92 ±  8.19
# ---------------- [48 / 64]
# Running ICCapv_ha--CONFIG_3--GradientBoostingRegressor
# The best hyperparameters are  {'subsample': 0.75, 'n_estimators': 100, 'max_leaf_nodes': 100, 'max_depth': 2, 'learning_rate': 0.1}
# metrics, predictions and models saved to
#  results/metrics--ICCapv_ha--CONFIG_3--GradientBoostingRegressor.pickle
#         R2    0.14 ±  0.13
#       MAPE    1.62 ±  0.73
#       RMSE    1.07 ±  0.12
#      NRMSE   62.87 ±  8.09
# ---------------- [49 / 64]
# Running Catot_ha--CONFIG_0--CatBoostRegressor
# The best hyperparameters are  {'learning_rate': 0.03, 'l2_leaf_reg': 4, 'iterations': 150, 'depth': 6}
# metrics, predictions and models saved to
#  results/metrics--Catot_ha--CONFIG_0--CatBoostRegressor.pickle
#         R2    0.29 ±  0.04
#       MAPE    2.57 ±  1.62
#       RMSE   51.61 ±  4.69
#      NRMSE   67.12 ±  7.56
# ---------------- [50 / 64]
# Running ICCapv_ha--CONFIG_0--CatBoostRegressor
# The best hyperparameters are  {'learning_rate': 0.03, 'l2_leaf_reg': 0.5, 'iterations': 150, 'depth': 2}
# metrics, predictions and models saved to
#  results/metrics--ICCapv_ha--CONFIG_0--CatBoostRegressor.pickle
#         R2    0.28 ±  0.09
#       MAPE    1.63 ±  0.74
#       RMSE    0.98 ±  0.12
#      NRMSE   57.74 ±  7.99
# ---------------- [51 / 64]
# Running Catot_ha--CONFIG_1--CatBoostRegressor
# The best hyperparameters are  {'learning_rate': 0.03, 'l2_leaf_reg': 0.5, 'iterations': 150, 'depth': 2}
# metrics, predictions and models saved to
#  results/metrics--Catot_ha--CONFIG_1--CatBoostRegressor.pickle
#         R2    0.68 ±  0.06
#       MAPE    1.32 ±  0.87
#       RMSE   34.52 ±  5.23
#      NRMSE   44.92 ±  7.65
# ---------------- [52 / 64]
# Running ICCapv_ha--CONFIG_1--CatBoostRegressor
# The best hyperparameters are  {'learning_rate': 0.1, 'l2_leaf_reg': 3, 'iterations': 200, 'depth': 6}
# metrics, predictions and models saved to
#  results/metrics--ICCapv_ha--CONFIG_1--CatBoostRegressor.pickle
#         R2     0.4 ±  0.12
#       MAPE    1.21 ±  0.56
#       RMSE    0.89 ±  0.13
#      NRMSE   52.76 ±  8.56
# ---------------- [53 / 64]
# Running Catot_ha--CONFIG_2--CatBoostRegressor
# The best hyperparameters are  {'learning_rate': 0.03, 'l2_leaf_reg': 0.5, 'iterations': 150, 'depth': 2}
# metrics, predictions and models saved to
#  results/metrics--Catot_ha--CONFIG_2--CatBoostRegressor.pickle
#         R2    0.68 ±  0.06
#       MAPE     1.3 ±  0.84
#       RMSE   34.91 ±  5.18
#      NRMSE   45.43 ±  7.62
# ---------------- [54 / 64]
# Running ICCapv_ha--CONFIG_2--CatBoostRegressor
# The best hyperparameters are  {'learning_rate': 0.03, 'l2_leaf_reg': 0.5, 'iterations': 150, 'depth': 2}
# metrics, predictions and models saved to
#  results/metrics--ICCapv_ha--CONFIG_2--CatBoostRegressor.pickle
#         R2    0.42 ±  0.12
#       MAPE    1.24 ±  0.53
#       RMSE    0.88 ±  0.15
#      NRMSE   51.88 ±  9.53
# ---------------- [55 / 64]
# Running Catot_ha--CONFIG_3--CatBoostRegressor
# The best hyperparameters are  {'learning_rate': 0.03, 'l2_leaf_reg': 4, 'iterations': 150, 'depth': 6}
# metrics, predictions and models saved to
#  results/metrics--Catot_ha--CONFIG_3--CatBoostRegressor.pickle
#         R2    0.31 ±  0.04
#       MAPE    2.57 ±  1.66
#       RMSE   51.04 ±  4.69
#      NRMSE   66.39 ±  7.54
# ---------------- [56 / 64]
# Running ICCapv_ha--CONFIG_3--CatBoostRegressor
# The best hyperparameters are  {'learning_rate': 0.1, 'l2_leaf_reg': 1, 'iterations': 100, 'depth': 2}
# metrics, predictions and models saved to
#  results/metrics--ICCapv_ha--CONFIG_3--CatBoostRegressor.pickle
#         R2    0.25 ±  0.13
#       MAPE    1.63 ±  0.74
#       RMSE     1.0 ±  0.14
#      NRMSE   59.21 ±  9.36
# ---------------- [57 / 64]
# Running Catot_ha--CONFIG_0--XGBRegressor
# The best hyperparameters are  {'n_estimators': 800, 'max_depth': 4, 'learning_rate': 0.015}
# metrics, predictions and models saved to
#  results/metrics--Catot_ha--CONFIG_0--XGBRegressor.pickle
#         R2    0.24 ±   0.1
#       MAPE    2.02 ±  1.06
#       RMSE   53.42 ±  4.53
#      NRMSE   69.46 ±   7.2
# ---------------- [58 / 64]
# Running ICCapv_ha--CONFIG_0--XGBRegressor
# The best hyperparameters are  {'n_estimators': 700, 'max_depth': 4, 'learning_rate': 0.01}
# metrics, predictions and models saved to
#  results/metrics--ICCapv_ha--CONFIG_0--XGBRegressor.pickle
#         R2    0.17 ±  0.14
#       MAPE    1.57 ±   0.7
#       RMSE    1.05 ±  0.11
#      NRMSE    62.0 ±  7.74
# ---------------- [59 / 64]
# Running Catot_ha--CONFIG_1--XGBRegressor
# The best hyperparameters are  {'n_estimators': 700, 'max_depth': 4, 'learning_rate': 0.01}
# metrics, predictions and models saved to
#  results/metrics--Catot_ha--CONFIG_1--XGBRegressor.pickle
#         R2    0.67 ±  0.07
#       MAPE    0.69 ±  0.29
#       RMSE   35.24 ±  5.27
#      NRMSE   45.84 ±  7.67
# ---------------- [60 / 64]
# Running ICCapv_ha--CONFIG_1--XGBRegressor
# The best hyperparameters are  {'n_estimators': 600, 'max_depth': 5, 'learning_rate': 0.02}
# metrics, predictions and models saved to
#  results/metrics--ICCapv_ha--CONFIG_1--XGBRegressor.pickle
#         R2    0.31 ±  0.11
#       MAPE    1.13 ±   0.4
#       RMSE    0.96 ±  0.13
#      NRMSE   56.52 ±  8.36
# ---------------- [61 / 64]
# Running Catot_ha--CONFIG_2--XGBRegressor
# The best hyperparameters are  {'n_estimators': 500, 'max_depth': 5, 'learning_rate': 0.015}
# metrics, predictions and models saved to
#  results/metrics--Catot_ha--CONFIG_2--XGBRegressor.pickle
#         R2    0.67 ±  0.06
#       MAPE     0.7 ±  0.35
#       RMSE   35.02 ±  5.18
#      NRMSE   45.55 ±  7.49
# ---------------- [62 / 64]
# Running ICCapv_ha--CONFIG_2--XGBRegressor
# The best hyperparameters are  {'n_estimators': 700, 'max_depth': 4, 'learning_rate': 0.01}
# metrics, predictions and models saved to
#  results/metrics--ICCapv_ha--CONFIG_2--XGBRegressor.pickle
#         R2    0.35 ±  0.12
#       MAPE    1.08 ±  0.39
#       RMSE    0.93 ±  0.14
#      NRMSE   54.99 ±  9.25
# ---------------- [63 / 64]
# Running Catot_ha--CONFIG_3--XGBRegressor
# The best hyperparameters are  {'n_estimators': 700, 'max_depth': 4, 'learning_rate': 0.01}
# metrics, predictions and models saved to
#  results/metrics--Catot_ha--CONFIG_3--XGBRegressor.pickle
#         R2    0.28 ±  0.08
#       MAPE    2.05 ±  1.05
#       RMSE   51.76 ±  4.08
#      NRMSE   67.29 ±  6.47
# ---------------- [64 / 64]
# Running ICCapv_ha--CONFIG_3--XGBRegressor
# The best hyperparameters are  {'n_estimators': 700, 'max_depth': 4, 'learning_rate': 0.01}
# metrics, predictions and models saved to
#  results/metrics--ICCapv_ha--CONFIG_3--XGBRegressor.pickle
#         R2    0.17 ±  0.13
#       MAPE    1.59 ±  0.72
#       RMSE    1.05 ±  0.11
#      NRMSE   62.02 ±  7.77

# %%
import shutil

if os.path.exists("catboost_info"):
    shutil.rmtree("catboost_info")
